# %%
import pandas as pd

df=pd.read_csv('https://raw.githubusercontent.com/Cora1218/pandas/main/store_sales.csv')
df1=pd.read_csv('https://raw.githubusercontent.com/Cora1218/pandas/main/date_info.csv')
df2=pd.read_csv('https://raw.githubusercontent.com/Cora1218/pandas/main/store_info.csv')

df3 =pd.merge(pd.merge(df,df1,left_on='sales_datetime', right_on='calendar_date'),df2,left_on='id', right_on='store_id')
df3

df4 = df3.groupby('sales_datetime')
df4.first()
# Out:
#                               id  sales_count calendar_date day_of_week  \
# sales_datetime
# 01/01/2016      db80363d35f10926            5    01/01/2016      Friday
# 01/01/2017      db80363d35f10926            2    01/01/2017      Sunday
# 01/02/2016      db80363d35f10926            2    01/02/2016      Monday
# 01/02/2017      db80363d35f10926            7    01/02/2017   Wednesday
# 01/03/2016      24b9b2a020826ede            3    01/03/2016     Tuesday
# ...                          ...          ...           ...         ...
# 31/03/2016      24b9b2a020826ede            2    31/03/2016    Thursday
# 31/03/2017      24b9b2a020826ede            2    31/03/2017      Friday
# 31/05/2016      db80363d35f10926           44    31/05/2016     Tuesday
# 31/10/2016      db80363d35f10926            3    31/10/2016      Monday
# 31/12/2016      1033310359ceeac1            8    31/12/2016    Saturday
#
#                 holiday_flg          store_id  store_type    zone_name  \
# sales_datetime
# 01/01/2016                1  db80363d35f10926  HOT & COLD          GDL
# 01/01/2017                1  db80363d35f10926  HOT & COLD          GDL
# 01/02/2016                0  db80363d35f10926  HOT & COLD          GDL
# 01/02/2017                0  db80363d35f10926  HOT & COLD          GDL
# 01/03/2016                0  24b9b2a020826ede  HOT & COLD          GDL
# ...                     ...               ...         ...          ...
# 31/03/2016                0  24b9b2a020826ede  HOT & COLD          GDL
# 31/03/2017                0  24b9b2a020826ede  HOT & COLD          GDL
# 31/05/2016                0  db80363d35f10926  HOT & COLD          GDL
# 31/10/2016                0  db80363d35f10926  HOT & COLD          GDL
# 31/12/2016                1  1033310359ceeac1        COLD  CDMX CENTER
#
#                  latitude   longitude
# sales_datetime
# 01/01/2016      20.644773 -103.412269
# 01/01/2017      20.644773 -103.412269
# 01/02/2016      20.644773 -103.412269
# 01/02/2017      20.644773 -103.412269
# 01/03/2016      20.644773 -103.412269
# ...                   ...         ...
# 31/03/2016      20.644773 -103.412269
# 31/03/2017      20.644773 -103.412269
# 31/05/2016      20.644773 -103.412269
# 31/10/2016      20.644773 -103.412269
# 31/12/2016      19.434118  -99.138895
#
# [416 rows x 10 columns]
